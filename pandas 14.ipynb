# %% [markdown]
# # Exercise 14
# ### Write a Pandas program to display the dataframe in Heatmap style.

# %%
import pandas as pd

# %%
df14 = pd.DataFrame(np.random.choice(a=1000, size=(20,20), replace=False))
# Palette
a = 'magma'   
b = 'viridis'

def gradient_map(data, palette):
    return data.style.background_gradient(cmap= palette)

# %%
gradient_map(df14, a)
# Out:
# <style type="text/css">
# #T_691cf_row0_col0, #T_691cf_row0_col18, #T_691cf_row11_col4, #T_691cf_row13_col1, #T_691cf_row14_col18 {
#   background-color: #59157e;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col1, #T_691cf_row13_col7, #T_691cf_row14_col14, #T_691cf_row16_col1 {
#   background-color: #ba3878;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col2, #T_691cf_row4_col9 {
#   background-color: #fc8c63;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col3, #T_691cf_row8_col6, #T_691cf_row18_col2 {
#   background-color: #7c2382;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col4, #T_691cf_row7_col0, #T_691cf_row8_col3, #T_691cf_row8_col12, #T_691cf_row16_col8 {
#   background-color: #721f81;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col5, #T_691cf_row15_col6 {
#   background-color: #febd82;
#   color: #000000;
# }
# #T_691cf_row0_col6 {
#   background-color: #21114e;
#   color: #f1f1f1;
# }
# #T_691cf_row0_col7, #T_691cf_row7_col2 {
#   background-color: #fea36f;
#   color: #000000;
# }
# ...
